# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
url="https://www.pilotjobsnetwork.com/jobs/Brussels_Airlines"
tables=pd.read_html(url)

# %%
df_salary=tables[3]

# %%
df_salary.head(10)
# Out:
#                                                    0  \
# 0                                                NaN
# 1  Brief Payscale (please state whether before or...
# 2                                           Capt top
# 3                                          Capt base
# 4                                             FO top
# 5                                            FO base
# 6                                             SO top
# 7                                            SO base
# 8                                             FE top
# 9                                            FE base
#
#                                                    1            2
# 0                                                NaN          NaN
# 1  Brief Payscale (please state whether before or...  last update
# 2                                              12559    24/Oct/19
# 3                                               7944    24/Oct/19
# ...

# %%
df_currency=tables[1]
df_currency.head()
# Out:
#                                                    0  \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1                                    Effective from:
# 2                                          Currency:
# 3                                   Addtional notes:
#
#                                                    1  \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1                                                NaN
# 2    Euro (click here to use the currency converter)
# 3  Monthly salary before tax Airbus sector + 10%....
#
#                                                    2  \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1        Listed pay rates are:  (yearly, hourly etc)
# 2                 Guaranteed hours:  (if applicable)
# 3                                                NaN
#
#                                                    3
# 0  Pilots' Detailed Payscale- please state whethe...
# ...

# %%
df_geography=tables[0]
df_geography.head()
# Out:
#                                                   0   \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1                                                NaN
# 2                                              Fleet
# 3                                               Rank
# 4                                               Year
#
#                                                   1   \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1                                                NaN
# 2                                               A32F
# 3                                                F/O
# 4                                                NaN
#
#                                                   2   \
# 0  Pilots' Detailed Payscale- please state whethe...
# 1                                                NaN
# 2                                               A330
# 3                                                F/O
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

url = "https://www.pilotjobsnetwork.com/jobs/Brussels_Airlines"

driver = webdriver.Firefox()
driver.get(url)

#print(driver.title)
#assert "Immoweb" in driver.title

time.sleep(3)
cookie_button = driver.find_element(By.XPATH, "//*[@id='uc-btn-accept-banner']")
time.sleep(1)
cookie_button.click()
time.sleep(1)


page_urls = []
table_rows = driver.find_elements(By.XPATH, "//tr[@class = 'classified-table__row']")
for table_row in table_rows:
    try:
        tr_header = table_row.find_element(By.XPATH, ".//th")
        tr_data = table_row.find_element(By.XPATH, ".//td")
    except NoSuchElementException:
        pass

    #print(table_row.text)
    print(tr_header.text)
    print(tr_data.text)
    #print(type(tr_data)) #Elément
    #print(type(tr_data.text))

driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/common/service.py:97, in Service.start(self)
#      96 try:
# ---> 97     path = SeleniumManager.driver_location(browser)
#      98 except WebDriverException as new_err:
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/common/selenium_manager.py:68, in SeleniumManager.driver_location(browser)
#      67 args = (str(SeleniumManager.get_binary()), "--browser", browser)
# ---> 68 result = SeleniumManager.run(args)
#      69 command = result.split("\t")[-1].strip()
#
# File /usr/local/lib/python3.10/site-packages/selenium/webdriver/common/selenium_manager.py:85, in SeleniumManager.run(args)
#      84 if not re.match("^INFO\t", result):
# ---> 85     raise WebDriverException(f"Unsuccessful command executed: {args}")
#      87 return result
#
# ...
